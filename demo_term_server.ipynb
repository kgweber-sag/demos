# %% [markdown]
# # Terminology Server API Demonstration
#
# Let's set up and then build a function that can help us exercise the API

# %%
import json
import os
from pprint import pprint as pp

import dotenv
import requests

dotenv.load_dotenv()


base_url = os.environ.get("TERM_SERVER_URL")

# %% [markdown]
# ## Search Helper
#
# This function helps us send a search request to the terminology server

# %%
def search(chunks, vocab=[], valuesets=[], domain_id=[], topk=15):
    url = base_url + "/search"

    headers = {"Content-Type": "application/json"}
    payload = {"chunks": chunks,
               "vocabulary_id": vocab,
               "domain_id": domain_id,
               "valueset_metadata_ids": valuesets,
               "topk": topk,
               "filter_by_valueset": len(valuesets) > 0}
    response = requests.post(url, headers=headers, data=json.dumps(payload))
    return response.json()

# %%
sample_chunks = ["cough"]
response = search(
    chunks=sample_chunks,

    topk=30,
    # valuesets=[5],
    domain_id=["Condition"]
)
pp(response)
# Out:
# {'cough': [{'chunk': 'cough',
#             'cmetadata': {'ID': 46431,
#                           'chunk_concept_id': 45606792,
#                           'concept_class_concept_id': 45754906,
#                           'concept_class_id': 'ICD10 Hierarchy',
#                           'concept_class_name': 'ICD10 Hierarchy',
#                           'concept_code': 'R05',
#                           'concept_name': 'cough and cold preparations',
#                           'domain_concept_id': 19,
#                           'domain_id': 'Condition',
#                           'domain_name': 'Condition',
#                           'source': 'Athena',
#                           'standard_concept': 'Non-Standard',
#                           'valid_end_date': '2099-12-31',
#                           'valid_start_date': '1990-05-01',
#                           'validity': True,
#                           'vocabulary_concept_id': 44819124,
#                           'vocabulary_id': 'ICD10',
#                           'vocabulary_name': 'International Classification of '
#                                              'Diseases, Tenth Revision (WHO)'},
#             'code_map_records': {},
#             'document': 'cough',
#             'score': 1.0,
#             'value_set_records': []},
#            {'chunk': 'cough',
#             'cmetadata': {'ID': 7249291,
#                           'chunk_concept_id': 35211275,
#                           'concept_class_concept_id': 46233658,
#                           'concept_class_id': '3-char nonbill code',
#                           'concept_class_name': '3-character non-billing code',
#                           'concept_code': 'R05',
#                           'concept_name': 'cough and cold preparations',
#                           'concept_name_detailed': 'cough (finding) [cough]',
#                           'domain_concept_id': 19,
#                           'domain_id': 'Condition',
#                           'domain_name': 'Condition',
#                           'source': 'JSL',
#                           'standard_concept': 'Non-Standard',
#                           'validity': False,
#                           'vocabulary_concept_id': 44819098,
#                           'vocabulary_id': 'ICD10CM',
#                           'vocabulary_name': 'International Classification of '
#                                              'Diseases, Tenth Revision, '
#                                              'Clinical Modification (NCHS)'},
#             'code_map_records': {},
#             'document': 'cough (finding)',
#             'score': 0.8095,
#             'value_set_records': []},
#            {'chunk': 'cough',
#             'cmetadata': {'ID': 46438,
#                           'chunk_concept_id': 254761,
#                           'concept_class_concept_id': 44818997,
#                           'concept_class_id': 'Clinical Finding',
#                           'concept_class_name': 'Clinical Finding',
#                           'concept_code': '49727002',
#                           'concept_name': 'cough',
#                           'domain_concept_id': 19,
#                           'domain_id': 'Condition',
#                           'domain_name': 'Condition',
#                           'source': 'Athena',
#                           'standard_concept': 'Standard',
#                           'valid_end_date': '2099-12-31',
#                           'valid_start_date': '2002-01-31',
#                           'validity': True,
#                           'vocabulary_concept_id': 44819097,
#                           'vocabulary_id': 'SNOMED',
#                           'vocabulary_name': 'Systematic Nomenclature of '
#                                              'Medicine - Clinical Terms '
#                                              '(IHTSDO)'},
#             'code_map_records': {},
#             'document': 'cough',
#             'score': 1.0,
#             'value_set_records': []},
#            {'chunk': 'cough',
#             'cmetadata': {'ID': 5821211,
#                           'chunk_concept_id': 4122567,
#                           'concept_class_concept_id': 44818997,
#                           'concept_class_id': 'Clinical Finding',
#                           'concept_class_name': 'Clinical Finding',
#                           'concept_code': '289114008',
#                           'concept_name': 'does cough',
#                           'domain_concept_id': 19,
#                           'domain_id': 'Condition',
#                           'domain_name': 'Condition',
#                           'source': 'Athena',
#                           'standard_concept': 'Standard',
#                           'valid_end_date': '2099-12-31',
#                           'valid_start_date': '2002-01-31',
#                           'validity': True,
#                           'vocabulary_concept_id': 44819097,
#                           'vocabulary_id': 'SNOMED',
#                           'vocabulary_name': 'Systematic Nomenclature of '
#                                              'Medicine - Clinical Terms '
#                                              '(IHTSDO)'},
#             'code_map_records': {},
#             'document': 'does cough',
#             'score': 0.8446,
#             'value_set_records': []},
#            {'chunk': 'cough',
#             'cmetadata': {'ID': 4185348,
#                           'chunk_concept_id': 4102774,
#                           'concept_class_concept_id': 44818997,
#                           'concept_class_id': 'Clinical Finding',
#                           'concept_class_name': 'Clinical Finding',
#                           'concept_code': '28743005',
#                           'concept_name': 'productive cough',
#                           'domain_concept_id': 19,
#                           'domain_id': 'Condition',
#                           'domain_name': 'Condition',
#                           'source': 'JSL',
#                           'standard_concept': 'Standard',
#                           'valid_end_date': '2099-12-31',
#                           'valid_start_date': '2002-01-31',
#                           'validity': True,
#                           'vocabulary_concept_id': 44819097,
#                           'vocabulary_id': 'SNOMED',
#                           'vocabulary_name': 'Systematic Nomenclature of '
#                                              'Medicine - Clinical Terms '
#                                              '(IHTSDO)'},
#             'code_map_records': {},
#             'document': 'bronchial cough',
#             'score': 0.8244,
#             'value_set_records': []},
#            {'chunk': 'cough',
#             'cmetadata': {'ID': 46433,
#                           'chunk_concept_id': 44828154,
#                           'concept_class_concept_id': 45754869,
#                           'concept_class_id': '4-dig billing code',
#                           'concept_class_name': '4-digit billing code',
#                           'concept_code': '786.2',
#                           'concept_name': 'cough',
#                           'domain_concept_id': 19,
#                           'domain_id': 'Condition',
#                           'domain_name': 'Condition',
#                           'source': 'Athena',
#                           'standard_concept': 'Non-Standard',
#                           'valid_end_date': '2099-12-31',
#                           'valid_start_date': '1970-01-01',
#                           'validity': True,
#                           'vocabulary_concept_id': 5046,
#                           'vocabulary_id': 'ICD9CM',
#                           'vocabulary_name': 'International Classification of '
#                                              'Diseases, Ninth Revision, '
#                                              'Clinical Modification, Volume 1 '
#                                              'and 2 (NCHS)'},
#             'code_map_records': {},
#             'document': 'cough',
#             'score': 1.0,
#             'value_set_records': []},
#            {'chunk': 'cough',
#             'cmetadata': {'ID': 7953260,
#                           'chunk_concept_id': 45612914,
#                           'concept_class_concept_id': 46233638,
#                           'concept_class_id': 'Main Heading',
#                           'concept_class_name': 'Main Heading or Descriptor',
#                           'concept_code': 'D003371',
#                           'concept_name': 'cough',
#                           'domain_concept_id': 19,
#                           'domain_id': 'Condition',
#                           'domain_name': 'Condition',
#                           'source': 'JSL',
#                           'standard_concept': 'Non-Standard',
#                           'validity': False,
#                           'vocabulary_concept_id': 44819136,
#                           'vocabulary_id': 'MeSH',
#                           'vocabulary_name': 'Medical Subject Headings (NLM)'},
#             'code_map_records': {},
#             'document': 'cough',
#             'score': 1.0,
#             'value_set_records': []},
#            {'chunk': 'cough',
#             'cmetadata': {'ID': 2366412,
#                           'chunk_concept_id': 1340293,
#                           'concept_class_concept_id': 44818997,
#                           'concept_class_id': 'Clinical Finding',
#                           'concept_class_name': 'Clinical Finding',
#                           'concept_code': 'OMOP5165948',
#                           'concept_name': 'exacerbation of cough',
#                           'domain_concept_id': 19,
#                           'domain_id': 'Condition',
#                           'domain_name': 'Condition',
#                           'source': 'Athena',
#                           'standard_concept': 'Standard',
#                           'valid_end_date': '2099-12-31',
#                           'valid_start_date': '2022-05-06',
#                           'validity': True,
#                           'vocabulary_concept_id': 32758,
#                           'vocabulary_id': 'OMOP Extension',
#                           'vocabulary_name': 'OMOP Extension (OHDSI)'},
#             'code_map_records': {},
#             'document': 'exacerbation of cough',
#             'score': 0.7721,
#             'value_set_records': []}]}

# %%
valuesets = requests.get(base_url + "/api/valuesets")
valuesets.json()
# Out:
# ---------------------------------------------------------------------------
# ConnectionRefusedError                    Traceback (most recent call last)
# File ~/miniconda3/envs/jsl/lib/python3.11/site-packages/urllib3/connection.py:199, in HTTPConnection._new_conn(self)
#     198 try:
# --> 199     sock = connection.create_connection(
#     200         (self._dns_host, self.port),
#     201         self.timeout,
#     202         source_address=self.source_address,
#     203         socket_options=self.socket_options,
#     204     )
#     205 except socket.gaierror as e:
#
# File ~/miniconda3/envs/jsl/lib/python3.11/site-packages/urllib3/util/connection.py:85, in create_connection(address, timeout, source_address, socket_options)
#      84 try:
# ---> 85     raise err
#      86 finally:
#      87     # Break explicitly a reference cycle
#
# File ~/miniconda3/envs/jsl/lib/python3.11/site-packages/urllib3/util/connection.py:73, in create_connection(address, timeout, source_address, socket_options)
#      72     sock.bind(source_address)
# ---> 73 sock.connect(sa)
#      74 # Break explicitly a reference cycle
#
# ConnectionRefusedError: [Errno 61] Connection refused
#
# The above exception was the direct cause of the following exception:
#
# NewConnectionError                        Traceback (most recent call last)
# File ~/miniconda3/envs/jsl/lib/python3.11/site-packages/urllib3/connectionpool.py:789, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     788 # Make the request on the HTTPConnection object
# --> 789 response = self._make_request(
#     790     conn,
#     791     method,
#     792     url,
#     793     timeout=timeout_obj,
#     794     body=body,
#     795     headers=headers,
#     796     chunked=chunked,
#     797     retries=retries,
#     798     response_conn=response_conn,
#     799     preload_content=preload_content,
#     800     decode_content=decode_content,
#     801     **response_kw,
#     802 )
#     804 # Everything went great!
#
# File ~/miniconda3/envs/jsl/lib/python3.11/site-packages/urllib3/connectionpool.py:495, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     494 try:
# --> 495     conn.request(
#     496         method,
#     497         url,
#     498         body=body,
#     499         headers=headers,
#     500         chunked=chunked,
#     501         preload_content=preload_content,
#     502         decode_content=decode_content,
#     503         enforce_content_length=enforce_content_length,
#     504     )
#     506 # We are swallowing BrokenPipeError (errno.EPIPE) since the server is
#     507 # legitimately able to close the connection after sending a valid response.
#     508 # With this behaviour, the received response is still readable.
#
# File ~/miniconda3/envs/jsl/lib/python3.11/site-packages/urllib3/connection.py:441, in HTTPConnection.request(self, method, url, body, headers, chunked, preload_content, decode_content, enforce_content_length)
#     440     self.putheader(header, value)
# --> 441 self.endheaders()
#     443 # If we're given a body we start sending that in chunks.
#
# File ~/miniconda3/envs/jsl/lib/python3.11/http/client.py:1298, in HTTPConnection.endheaders(self, message_body, encode_chunked)
#    1297     raise CannotSendHeader()
# -> 1298 self._send_output(message_body, encode_chunked=encode_chunked)
#
# File ~/miniconda3/envs/jsl/lib/python3.11/http/client.py:1058, in HTTPConnection._send_output(self, message_body, encode_chunked)
#    1057 del self._buffer[:]
# -> 1058 self.send(msg)
#    1060 if message_body is not None:
#    1061
#    1062     # create a consistent interface to message_body
#
# File ~/miniconda3/envs/jsl/lib/python3.11/http/client.py:996, in HTTPConnection.send(self, data)
#     995 if self.auto_open:
# --> 996     self.connect()
#     997 else:
#
# File ~/miniconda3/envs/jsl/lib/python3.11/site-packages/urllib3/connection.py:279, in HTTPConnection.connect(self)
#     278 def connect(self) -> None:
# --> 279     self.sock = self._new_conn()
#     280     if self._tunnel_host:
#     281         # If we're tunneling it means we're connected to our proxy.
#
# File ~/miniconda3/envs/jsl/lib/python3.11/site-packages/urllib3/connection.py:214, in HTTPConnection._new_conn(self)
#     213 except OSError as e:
# --> 214     raise NewConnectionError(
#     215         self, f"Failed to establish a new connection: {e}"
#     216     ) from e
#     218 # Audit hooks are only available in Python 3.8+
#
# NewConnectionError: <urllib3.connection.HTTPConnection object at 0x1087d0350>: Failed to establish a new connection: [Errno 61] Connection refused
#
# The above exception was the direct cause of the following exception:
#
# MaxRetryError                             Traceback (most recent call last)
# File ~/miniconda3/envs/jsl/lib/python3.11/site-packages/requests/adapters.py:667, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     666 try:
# --> 667     resp = conn.urlopen(
#     668         method=request.method,
#     669         url=url,
#     670         body=request.body,
#     671         headers=request.headers,
#     672         redirect=False,
#     673         assert_same_host=False,
#     674         preload_content=False,
#     675         decode_content=False,
#     676         retries=self.max_retries,
#     677         timeout=timeout,
#     678         chunked=chunked,
#     679     )
#     681 except (ProtocolError, OSError) as err:
#
# File ~/miniconda3/envs/jsl/lib/python3.11/site-packages/urllib3/connectionpool.py:843, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     841     new_e = ProtocolError("Connection aborted.", new_e)
# --> 843 retries = retries.increment(
#     844     method, url, error=new_e, _pool=self, _stacktrace=sys.exc_info()[2]
#     845 )
#     846 retries.sleep()
#
# File ~/miniconda3/envs/jsl/lib/python3.11/site-packages/urllib3/util/retry.py:519, in Retry.increment(self, method, url, response, error, _pool, _stacktrace)
#     518     reason = error or ResponseError(cause)
# --> 519     raise MaxRetryError(_pool, url, reason) from reason  # type: ignore[arg-type]
#     521 log.debug("Incremented Retry for (url='%s'): %r", url, new_retry)
#
# MaxRetryError: HTTPConnectionPool(host='34.202.244.73', port=8080): Max retries exceeded with url: /api/valuesets (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x1087d0350>: Failed to establish a new connection: [Errno 61] Connection refused'))
#
# During handling of the above exception, another exception occurred:
#
# ConnectionError                           Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 valuesets = requests.get(base_url + "/api/valuesets")
#       2 valuesets.json()
#
# File ~/miniconda3/envs/jsl/lib/python3.11/site-packages/requests/api.py:73, in get(url, params, **kwargs)
#      62 def get(url, params=None, **kwargs):
#      63     r"""Sends a GET request.
#      64
#      65     :param url: URL for the new :class:`Request` object.
#    (...)
#      70     :rtype: requests.Response
#      71     """
# ---> 73     return request("get", url, params=params, **kwargs)
#
# File ~/miniconda3/envs/jsl/lib/python3.11/site-packages/requests/api.py:59, in request(method, url, **kwargs)
#      55 # By using the 'with' statement we are sure the session is closed, thus we
#      56 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      57 # cases, and look like a memory leak in others.
#      58 with sessions.Session() as session:
# ---> 59     return session.request(method=method, url=url, **kwargs)
#
# File ~/miniconda3/envs/jsl/lib/python3.11/site-packages/requests/sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File ~/miniconda3/envs/jsl/lib/python3.11/site-packages/requests/sessions.py:703, in Session.send(self, request, **kwargs)
#     700 start = preferred_clock()
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#     706 elapsed = preferred_clock() - start
#
# File ~/miniconda3/envs/jsl/lib/python3.11/site-packages/requests/adapters.py:700, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     696     if isinstance(e.reason, _SSLError):
#     697         # This branch is for urllib3 v1.22 and later.
#     698         raise SSLError(e, request=request)
# --> 700     raise ConnectionError(e, request=request)
#     702 except ClosedPoolError as e:
#     703     raise ConnectionError(e, request=request)
#
# ConnectionError: HTTPConnectionPool(host='34.202.244.73', port=8080): Max retries exceeded with url: /api/valuesets (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x1087d0350>: Failed to establish a new connection: [Errno 61] Connection refused'))
